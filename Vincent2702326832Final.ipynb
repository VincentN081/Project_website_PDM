# %% [markdown]
# <a href="https://colab.research.google.com/github/VincentN081/Project_website_PDM/blob/main/Vincent2702326832Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
import numpy as np
import matplotlib.pyplot as plt

# %%
data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399,
    2048, 2523, 2086, 2391, 2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862,
    3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768, 3141, 3439, 3601, 3531,
    3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422,
    4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211,
    4880, 4933, 5079, 5339, 5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235,
    6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590, 6271, 7246, 6584, 6594,
    7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933,
    8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048,
    10244, 10740, 10318, 10393, 10986, 10635, 10731, 11749, 11849, 12123,
    12274, 11666, 11960, 12629, 12915, 13051, 13387, 13309, 13732, 13162,
    13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556, 15893,
    16388, 16782, 16716, 17033, 16896, 17689
]

months = np.arange(1, len(data) + 1)

# %%
import numpy as np
import matplotlib.pyplot as plt

# no 1

# Plotting datanya
plt.figure(figsize=(12, 6))
plt.plot(months, data, '-r', label='Monthly Production')
plt.xlabel('Month')
plt.ylabel('Production')
plt.title('Monthly Production Data (Jan 2018 - Dec 2023)')
plt.legend()
plt.grid(True)
plt.show()

# %%
#no 2

import numpy as np
import matplotlib.pyplot as plt
import math

data = np.array(data)
months = np.array(months)

# membuat fungsi polinomial
# copy koefisien dari fungsi
coefs = np.polyfit(months, data, 3)
polynomial = np.poly1d(coefs)
a, b, c, d = coefs


def taylor_series(x, a, b, c, d):
    return d + c*x + b*x**2 + a*x**3

# Calculate Taylor series values
taylor = taylor_series(months, a, b, c, d)
x = np.linspace(-2, 3, 400)

# Plot original data and Taylor series values
plt.figure(figsize=(10, 6))
plt.plot(months, data, label='Original Data')
plt.plot(months, taylor, label='Taylor Series')
plt.xlabel('Month')
plt.ylabel('Production')
plt.title('Bag Production Over Time')
plt.legend()
plt.show()

# %%
#no 3
from scipy.optimize import fsolve

data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399,
    2048, 2523, 2086, 2391, 2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862,
    3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768, 3141, 3439, 3601, 3531,
    3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422,
    4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211,
    4880, 4933, 5079, 5339, 5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235,
    6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590, 6271, 7246, 6584, 6594,
    7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933,
    8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048,
    10244, 10740, 10318, 10393, 10986, 10635, 10731, 11749, 11849, 12123,
    12274, 11666, 11960, 12629, 12915, 13051, 13387, 13309, 13732, 13162,
    13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556, 15893,
    16388, 16782, 16716, 17033, 16896, 17689
]

coeffs = np.polyfit(months, data, 3)
# buat fuction polynomial
def predictSto(month):
    return coeffs[0] * month**3 + coeffs[1] * month**2 + coeffs[2] * month + coeffs[3]

# maksimum dari storage
max_storage = 25000

# buat fungsi untuk cari root
def funcR(month):
    return predictSto(month) - max_storage

# cari bulan dimana storage melebihi capacity maksimum
root_m = fsolve(funcR, 200)[0]

# cari waktu EGIER harus mulai bangun warehouse baru
starting = int(root_m - 13)
start_y = 2018 + (starting // 12)
start_m = starting % 12
month_n = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"][int(start_m) - 1]

print(f"It is predicted EGIER will need to start building the new warehouse in {month_n} by the year {int(start_y)}.")
data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399,
    2048, 2523, 2086, 2391, 2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862,
    3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768, 3141, 3439, 3601, 3531,
    3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422,
    4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211,
    4880, 4933, 5079, 5339, 5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235,
    6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590, 6271, 7246, 6584, 6594,
    7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933,
    8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048,
    10244, 10740, 10318, 10393, 10986, 10635, 10731, 11749, 11849, 12123,
    12274, 11666, 11960, 12629, 12915, 13051, 13387, 13309, 13732, 13162,
    13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556, 15893,
    16388, 16782, 16716, 17033, 16896, 17689
]

coeffs = np.polyfit(months, data, 3)
# buat fuction polynomial
def predictSto(month):
    return coeffs[0] * month**3 + coeffs[1] * month**2 + coeffs[2] * month + coeffs[3]

# maksimum dari storage
max_storage = 25000

# buat fungsi untuk cari root
def funcR(month):
    return predictSto(month) - max_storage

# cari bulan dimana storage melebihi capacity maksimum
root_m = fsolve(funcR, 200)[0]

# cari waktu EGIER harus mulai bangun warehouse baru
starting = int(root_m - 13)
start_y = 2018 + (starting // 12)
start_m = starting % 12
month_n = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"][int(start_m) - 1]

print(f"It is predicted EGIER will need to start building the new warehouse in {month_n} by the year {int(start_y)}.")
# Out:
# It is predicted EGIER will need to start building the new warehouse in January by the year 2031.
# It is predicted EGIER will need to start building the new warehouse in January by the year 2031.
